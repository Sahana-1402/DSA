# %% [markdown]
# **Merge sort Implemetation**

# %%
#merge Procedure Implementation
def mergeProcedure(i, mid, j, arr):
  # length of the two arrays
  n1 = i - mid + 1
  n2 = j + mid

  #initialize the two arrays
  arrLeft = [0] * n1
  arrRight = [0] * n2

  #copy the array items
  for m in range(n1):
    arrLeft[m] = arr[i+m]
  for n in range(n1):
    arrRight[n] = arr[mid + 1 + n]

  #initialize the pointers
  p = 0
  q = 0
  k = 0

  #copy the array items
  while p < n1 and q < n2:
    if arrLeft[p] <= arrRight[q]:
      arr[k] = arrLeft[p]
      p+=1
    else:
      arr[k] = arrRight[q]
      q+=1
    k+=1

  while p < n1:
    arr[k] = arrLeft[p]
    p+=1
    k+=1

  print(q,n2)
  while q < n2:
    arr[k] = arrRight[q]
    q+=1
    k+=1

# mergeSort Implementation
def mergeSort(arr, i, j):
  if i < j:
    mid = i + (j - i) // 2
    mergeSort(arr, i, mid)
    mergeSort(arr, mid + 1, j)
    mergeProcedure(i, mid, j, arr)
  return arr

# Driver Code
arr = [23, 45, 76, 12, 35, 87, 89]
i = 0
j = len(arr) - 1
print(mergeSort(arr, i, j))
# Out:
# 0 1
# 5 5
# 0 4
# 0 9
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-33fc0ed0d148> in <cell line: 56>()
#      54 i = 0
#      55 j = len(arr) - 1
# ---> 56 print(mergeSort(arr, i, j))
#
# <ipython-input-10-33fc0ed0d148> in mergeSort(arr, i, j)
#      46     mid = i + (j - i) // 2
#      47     mergeSort(arr, i, mid)
# ---> 48     mergeSort(arr, mid + 1, j)
#      49     mergeProcedure(i, mid, j, arr)
#      50   return arr
#
# <ipython-input-10-33fc0ed0d148> in mergeSort(arr, i, j)
#      45   if i < j:
#      46     mid = i + (j - i) // 2
# ---> 47     mergeSort(arr, i, mid)
#      48     mergeSort(arr, mid + 1, j)
#      49     mergeProcedure(i, mid, j, arr)
#
# <ipython-input-10-33fc0ed0d148> in mergeSort(arr, i, j)
#      47     mergeSort(arr, i, mid)
#      48     mergeSort(arr, mid + 1, j)
# ---> 49     mergeProcedure(i, mid, j, arr)
# ...
