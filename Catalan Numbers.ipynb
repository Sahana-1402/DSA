# %% [markdown]
# Catalan Numbers

# %%
def catalan(n):
  #base case
  result = 0
  if n == 0 or n == 1:
    result += 1
  else:
    for i in range(0,n):
      result += (catalan(i)*catalan(n-1-i))
  return result

print(catalan(19))
# Out:
# 1767263190
